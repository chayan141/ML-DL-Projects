# %%
import matplotlib.pyplot as plt
img = plt.imread('/content/sample_data/Cristiano-Ronaldo-STACK.jpg')
plt.imshow(img)

# %%
plt.imshow(img[50:200,50:200,:])

# %%
# for row in range(0,600,50):
#   for col in range(0,200,50):
#     plt.imshow(img[row:row+50,col:col+50,:])
#     plt.show()

# %%
#TFOD-2 & Detectron are used for RCNN & SSD

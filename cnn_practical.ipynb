# %%
car_image_path = "/content/sample_data/car1 (1).jpeg"

# %%
import tensorflow as tf
import numpy as np
import matplotlib.pyplot as plt
import cv2

# %%
cv2.imread(car_image_path)
# Out:
# array([[[237, 237, 237],
#         [237, 237, 237],
#         [237, 237, 237],
#         ...,
#         [237, 237, 237],
#         [237, 237, 237],
#         [237, 237, 237]],
#
#        [[237, 237, 237],
#         [237, 237, 237],
#         [237, 237, 237],
#         ...,
#         [237, 237, 237],
#         [237, 237, 237],
#         [237, 237, 237]],
#
#        [[237, 237, 237],
#         [237, 237, 237],
#         [237, 237, 237],
#         ...,
#         [237, 237, 237],
#         [237, 237, 237],
#         [237, 237, 237]],
#
#        ...,
#
#        [[216, 216, 216],
#         [216, 216, 216],
#         [216, 216, 216],
#         ...,
#         [211, 211, 211],
#         [211, 211, 211],
#         [211, 211, 211]],
#
#        [[217, 217, 217],
#         [217, 217, 217],
#         [217, 217, 217],
#         ...,
#         [213, 213, 213],
#         [213, 213, 213],
#         [213, 213, 213]],
#
#        [[217, 217, 217],
#         [217, 217, 217],
#         [217, 217, 217],
#         ...,
#         [214, 214, 214],
#         [214, 214, 214],
#         [214, 214, 214]]], dtype=uint8)

# %%
img = cv2.imread(car_image_path)

# %%
plt.imshow(img) #convertes image RGB to BGR

# %%
#BGR to RGB Conversion
cv2.cvtColor(img,cv2.COLOR_BGR2RGB)
# Out:
# array([[[237, 237, 237],
#         [237, 237, 237],
#         [237, 237, 237],
#         ...,
#         [237, 237, 237],
#         [237, 237, 237],
#         [237, 237, 237]],
#
#        [[237, 237, 237],
#         [237, 237, 237],
#         [237, 237, 237],
#         ...,
#         [237, 237, 237],
#         [237, 237, 237],
#         [237, 237, 237]],
#
#        [[237, 237, 237],
#         [237, 237, 237],
#         [237, 237, 237],
#         ...,
#         [237, 237, 237],
#         [237, 237, 237],
#         [237, 237, 237]],
#
#        ...,
#
#        [[216, 216, 216],
#         [216, 216, 216],
#         [216, 216, 216],
#         ...,
#         [211, 211, 211],
#         [211, 211, 211],
#         [211, 211, 211]],
#
#        [[217, 217, 217],
#         [217, 217, 217],
#         [217, 217, 217],
#         ...,
#         [213, 213, 213],
#         [213, 213, 213],
#         [213, 213, 213]],
#
#        [[217, 217, 217],
#         [217, 217, 217],
#         [217, 217, 217],
#         ...,
#         [214, 214, 214],
#         [214, 214, 214],
#         [214, 214, 214]]], dtype=uint8)

# %%
cv2.cvtColor(img, cv2.COLOR_BGR2HSV)
# Out:
# array([[[  0,   0, 237],
#         [  0,   0, 237],
#         [  0,   0, 237],
#         ...,
#         [  0,   0, 237],
#         [  0,   0, 237],
#         [  0,   0, 237]],
#
#        [[  0,   0, 237],
#         [  0,   0, 237],
#         [  0,   0, 237],
#         ...,
#         [  0,   0, 237],
#         [  0,   0, 237],
#         [  0,   0, 237]],
#
#        [[  0,   0, 237],
#         [  0,   0, 237],
#         [  0,   0, 237],
#         ...,
#         [  0,   0, 237],
#         [  0,   0, 237],
#         [  0,   0, 237]],
#
#        ...,
#
#        [[  0,   0, 216],
#         [  0,   0, 216],
#         [  0,   0, 216],
#         ...,
#         [  0,   0, 211],
#         [  0,   0, 211],
#         [  0,   0, 211]],
#
#        [[  0,   0, 217],
#         [  0,   0, 217],
#         [  0,   0, 217],
#         ...,
#         [  0,   0, 213],
#         [  0,   0, 213],
#         [  0,   0, 213]],
#
#        [[  0,   0, 217],
#         [  0,   0, 217],
#         [  0,   0, 217],
#         ...,
#         [  0,   0, 214],
#         [  0,   0, 214],
#         [  0,   0, 214]]], dtype=uint8)

# %%
cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
# Out:
# array([[237, 237, 237, ..., 237, 237, 237],
#        [237, 237, 237, ..., 237, 237, 237],
#        [237, 237, 237, ..., 237, 237, 237],
#        ...,
#        [216, 216, 216, ..., 211, 211, 211],
#        [217, 217, 217, ..., 213, 213, 213],
#        [217, 217, 217, ..., 214, 214, 214]], dtype=uint8)

# %%
img2 = cv2.cvtColor(img,cv2.COLOR_BGR2RGB)

# %%
plt.imshow(img2)

# %%
img3 = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
plt.imshow(img3,cmap = 'gray')

# %%
img.shape
# Out:
# (168, 300, 3)

# %%
img2.shape
# Out:
# (168, 300, 3)

# %%
img3.shape
# Out:
# (168, 300)

# %%
from google.colab.patches import cv2_imshow
cv2_imshow(img)
# Out:
# <PIL.Image.Image image mode=RGB size=300x168>

# %%
img3.shape
# Out:
# (168, 300)

# %%
row,col = img3.shape

# %%
car = img3.reshape(1,row,col,1)
car.shape
# Out:
# (1, 168, 300, 1)

# %%
conv_layer = [tf.keras.layers.Conv2D(
    filters=1,
    kernel_size=(3,3),
    strides = (1,1),
    input_shape=car.shape[1:],
)]

# %%
conv_model = tf.keras.Sequential(conv_layer)

# %%
conv_model.summary()
# Out:
# Model: "sequential_5"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d_5 (Conv2D)           (None, 166, 298, 1)       10
#
# =================================================================
# Total params: 10 (40.00 Byte)
# Trainable params: 10 (40.00 Byte)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %%
output = conv_model.predict(car)
# Out:
# WARNING:tensorflow:6 out of the last 7 calls to <function Model.make_predict_function.<locals>.predict_function at 0x798a5d7a9e10> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has reduce_retracing=True option that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# 1/1 [==============================] - 0s 54ms/step

# %%
output.shape
# Out:
# (1, 166, 298, 1)

# %%
row,col = output.shape[1:-1]
reshaped_output = output.reshape(row,col)

# %%
plt.imshow(reshaped_output,cmap='gray')

# %%
car.shape[1:]
# Out:
# (168, 300, 1)

# %%
row, col,depth = img2.shape

# %%
color_car = img2

# %%
reshaped_color_image = color_car.reshape(1,row,col,depth)

# %%
CONV_LAYER = [tf.keras.layers.Conv2D(
    filters = 1,
    kernel_size = (3,3),
    strides = (1,1),
    input_shape=reshaped_color_image.shape[1:]
)]

conv_model = tf.keras.Sequential(CONV_LAYER)

# %%
img2.shape
# Out:
# (168, 300, 3)

# %%
conv_model.summary()
# Out:
# Model: "sequential_6"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d_6 (Conv2D)           (None, 166, 298, 1)       28
#
# =================================================================
# Total params: 28 (112.00 Byte)
# Trainable params: 28 (112.00 Byte)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %%
color_output = conv_model.predict(reshaped_color_image)
# Out:
# 1/1 [==============================] - 0s 51ms/step

# %%
row,col = color_output.shape[1:-1]
reshaped_out = color_output.reshape(row,col)

plt.imshow(reshaped_out,cmap='gray')

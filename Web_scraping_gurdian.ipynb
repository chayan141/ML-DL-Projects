# %%
import pandas as pd
API_KEY = "4d282cfc-e32b-49ee-b32c-c62ccf5c43e8"

# %%
url = 'https://content.guardianapis.com/world/narendra-modi?from-date=2021-01-01&api-key=4d282cfc-e32b-49ee-b32c-c62ccf5c43e8&type=article&page=1'

# %%
urllist = []
no_of_pages = 12
for i in range(1,no_of_pages):
  a = "https://content.guardianapis.com/world/narendra-modi?from-date=2021-01-01&api-key=4d282cfc-e32b-49ee-b32c-c62ccf5c43e8&type=article&page="
  b = str(i)
  c = a+b
  urllist.append(c)
urllist
# Out:
# ['https://content.guardianapis.com/world/narendra-modi?from-date=2021-01-01&api-key=4d282cfc-e32b-49ee-b32c-c62ccf5c43e8&type=article&page=1',
#  'https://content.guardianapis.com/world/narendra-modi?from-date=2021-01-01&api-key=4d282cfc-e32b-49ee-b32c-c62ccf5c43e8&type=article&page=2',
#  'https://content.guardianapis.com/world/narendra-modi?from-date=2021-01-01&api-key=4d282cfc-e32b-49ee-b32c-c62ccf5c43e8&type=article&page=3',
#  'https://content.guardianapis.com/world/narendra-modi?from-date=2021-01-01&api-key=4d282cfc-e32b-49ee-b32c-c62ccf5c43e8&type=article&page=4',
#  'https://content.guardianapis.com/world/narendra-modi?from-date=2021-01-01&api-key=4d282cfc-e32b-49ee-b32c-c62ccf5c43e8&type=article&page=5',
#  'https://content.guardianapis.com/world/narendra-modi?from-date=2021-01-01&api-key=4d282cfc-e32b-49ee-b32c-c62ccf5c43e8&type=article&page=6',
# ...

# %%
info=[]
import requests
def json(url1):
  response = requests.get(url1)
  x = response.json()
  info.append(x)

output = [json(url1) for url1 in urllist]
output
# Out:
# [None, None, None, None, None, None, None, None, None, None, None]

# %%
info
# Out:
# [{'response': {'status': 'ok',
#    'userTier': 'developer',
#    'total': 239,
#    'startIndex': 1,
#    'pageSize': 10,
#    'currentPage': 1,
#    'pages': 24,
#    'orderBy': 'newest',
#    'tag': {'id': 'world/narendra-modi',
#     'type': 'keyword',
#     'sectionId': 'world',
#     'sectionName': 'World news',
#     'webTitle': 'Narendra Modi',
#     'webUrl': 'https://www.theguardian.com/world/narendra-modi',
#     'apiUrl': 'https://content.guardianapis.com/world/narendra-modi'},
#    'results': [{'id': 'world/article/2024/jun/06/first-edition-india-election-modi-future',
#      'type': 'article',
#      'sectionId': 'world',
#      'sectionName': 'World news',
#      'webPublicationDate': '2024-06-06T05:49:38Z',
#      'webTitle': 'Thursday briefing: Narendra Modi reaches a crossroads as India denies him a majority in election upset',
#      'webUrl': 'https://www.theguardian.com/world/article/2024/jun/06/first-edition-india-election-modi-future',
# ...

# %%
info[0]['response']['results'][0]['webTitle']
# Out:
# 'Thursday briefing: Narendra Modi reaches a crossroads as India denies him a majority in election upset'

# %%
final=[]
try:
  for k in range(0,11):
    for j in range(0,10):
      value=dict(webtitle=info[k]['response']['results'][j]['webTitle'],
      sectionname = info[k]['response']['results'][j]['sectionName'],
      published_date = info[k]['response']['results'][j]['webPublicationDate'])
      final.append(value)
except IndexError:
  print('done')

final
# Out:
# [{'webtitle': 'Thursday briefing: Narendra Modi reaches a crossroads as India denies him a majority in election upset',
#   'sectionname': 'World news',
#   'published_date': '2024-06-06T05:49:38Z'},
#  {'webtitle': 'Narendra Modi wins backing of allies to form Indian government',
#   'sectionname': 'World news',
#   'published_date': '2024-06-05T18:28:43Z'},
#  {'webtitle': '‘Bit of a moment for Rahul Gandhi’: new dawn for India’s opposition, but where to now?',
#   'sectionname': 'World news',
#   'published_date': '2024-06-05T18:13:26Z'},
#  {'webtitle': 'The Guardian view on Modi’s election disappointment: the winner is democracy in India | Editorial',
#   'sectionname': 'Opinion',
#   'published_date': '2024-06-05T17:30:28Z'},
#  {'webtitle': 'How voters turned against Narendra Modi in his party’s heartland',
#   'sectionname': 'World news',
#   'published_date': '2024-06-05T15:25:05Z'},
# ...

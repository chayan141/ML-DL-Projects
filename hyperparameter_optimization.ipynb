# %%
import pandas as pd
import numpy as np
from sklearn import ensemble
from sklearn import metrics
from sklearn import model_selection

# %%
if __name__=='__main__':
  df = pd.read_csv('https://raw.githubusercontent.com/Nithya-Vasudevan/Mobile-Price-Classification/master/train.csv')
  X = df.drop('price_range', axis=1).values
  y = df.price_range.values

  classifier = ensemble.RandomForestClassifier(n_jobs=-1)
  param_grid = {
      'n_estimators':[100,200,300,400],
      'max_depth':[1,3,5,7],
      'criterion':['gini','entropy'],

  }
  model = model_selection.GridSearchCV(
      estimator=classifier,
      param_grid = param_grid,
      scoring = 'accuracy',
      verbose=10,
      n_jobs = 1,
      cv=5
  )

  model.fit(X,y)
# Out:
# Fitting 5 folds for each of 32 candidates, totalling 160 fits
# [CV 1/5; 1/32] START criterion=gini, max_depth=1, n_estimators=100..............
# [CV 1/5; 1/32] END criterion=gini, max_depth=1, n_estimators=100;, score=0.580 total time=   0.3s
# [CV 2/5; 1/32] START criterion=gini, max_depth=1, n_estimators=100..............
# [CV 2/5; 1/32] END criterion=gini, max_depth=1, n_estimators=100;, score=0.593 total time=   0.3s
# [CV 3/5; 1/32] START criterion=gini, max_depth=1, n_estimators=100..............
# [CV 3/5; 1/32] END criterion=gini, max_depth=1, n_estimators=100;, score=0.593 total time=   0.3s
# [CV 4/5; 1/32] START criterion=gini, max_depth=1, n_estimators=100..............
# [CV 4/5; 1/32] END criterion=gini, max_depth=1, n_estimators=100;, score=0.588 total time=   0.3s
# [CV 5/5; 1/32] START criterion=gini, max_depth=1, n_estimators=100..............
# [CV 5/5; 1/32] END criterion=gini, max_depth=1, n_estimators=100;, score=0.588 total time=   0.3s
# [CV 1/5; 2/32] START criterion=gini, max_depth=1, n_estimators=200..............
# [CV 1/5; 2/32] END criterion=gini, max_depth=1, n_estimators=200;, score=0.603 total time=   0.5s
# [CV 2/5; 2/32] START criterion=gini, max_depth=1, n_estimators=200..............
# [CV 2/5; 2/32] END criterion=gini, max_depth=1, n_estimators=200;, score=0.555 total time=   0.5s
# [CV 3/5; 2/32] START criterion=gini, max_depth=1, n_estimators=200..............
# [CV 3/5; 2/32] END criterion=gini, max_depth=1, n_estimators=200;, score=0.595 total time=   0.5s
# [CV 4/5; 2/32] START criterion=gini, max_depth=1, n_estimators=200..............
# [CV 4/5; 2/32] END criterion=gini, max_depth=1, n_estimators=200;, score=0.595 total time=   0.5s
# [CV 5/5; 2/32] START criterion=gini, max_depth=1, n_estimators=200..............
# [CV 5/5; 2/32] END criterion=gini, max_depth=1, n_estimators=200;, score=0.570 total time=   0.6s
# [CV 1/5; 3/32] START criterion=gini, max_depth=1, n_estimators=300..............
# [CV 1/5; 3/32] END criterion=gini, max_depth=1, n_estimators=300;, score=0.555 total time=   0.9s
# [CV 2/5; 3/32] START criterion=gini, max_depth=1, n_estimators=300..............
# [CV 2/5; 3/32] END criterion=gini, max_depth=1, n_estimators=300;, score=0.605 total time=   1.5s
# [CV 3/5; 3/32] START criterion=gini, max_depth=1, n_estimators=300..............
# [CV 3/5; 3/32] END criterion=gini, max_depth=1, n_estimators=300;, score=0.600 total time=   1.1s
# [CV 4/5; 3/32] START criterion=gini, max_depth=1, n_estimators=300..............
# [CV 4/5; 3/32] END criterion=gini, max_depth=1, n_estimators=300;, score=0.580 total time=   1.0s
# [CV 5/5; 3/32] START criterion=gini, max_depth=1, n_estimators=300..............
# [CV 5/5; 3/32] END criterion=gini, max_depth=1, n_estimators=300;, score=0.570 total time=   0.8s
# [CV 1/5; 4/32] START criterion=gini, max_depth=1, n_estimators=400..............
# [CV 1/5; 4/32] END criterion=gini, max_depth=1, n_estimators=400;, score=0.615 total time=   1.0s
# [CV 2/5; 4/32] START criterion=gini, max_depth=1, n_estimators=400..............
# [CV 2/5; 4/32] END criterion=gini, max_depth=1, n_estimators=400;, score=0.615 total time=   1.0s
# [CV 3/5; 4/32] START criterion=gini, max_depth=1, n_estimators=400..............
# [CV 3/5; 4/32] END criterion=gini, max_depth=1, n_estimators=400;, score=0.585 total time=   1.0s
# [CV 4/5; 4/32] START criterion=gini, max_depth=1, n_estimators=400..............
# [CV 4/5; 4/32] END criterion=gini, max_depth=1, n_estimators=400;, score=0.593 total time=   1.0s
# [CV 5/5; 4/32] START criterion=gini, max_depth=1, n_estimators=400..............
# [CV 5/5; 4/32] END criterion=gini, max_depth=1, n_estimators=400;, score=0.562 total time=   1.0s
# [CV 1/5; 5/32] START criterion=gini, max_depth=3, n_estimators=100..............
# [CV 1/5; 5/32] END criterion=gini, max_depth=3, n_estimators=100;, score=0.772 total time=   0.3s
# [CV 2/5; 5/32] START criterion=gini, max_depth=3, n_estimators=100..............
# [CV 2/5; 5/32] END criterion=gini, max_depth=3, n_estimators=100;, score=0.785 total time=   0.3s
# [CV 3/5; 5/32] START criterion=gini, max_depth=3, n_estimators=100..............
# [CV 3/5; 5/32] END criterion=gini, max_depth=3, n_estimators=100;, score=0.805 total time=   0.3s
# [CV 4/5; 5/32] START criterion=gini, max_depth=3, n_estimators=100..............
# [CV 4/5; 5/32] END criterion=gini, max_depth=3, n_estimators=100;, score=0.797 total time=   0.3s
# [CV 5/5; 5/32] START criterion=gini, max_depth=3, n_estimators=100..............
# [CV 5/5; 5/32] END criterion=gini, max_depth=3, n_estimators=100;, score=0.792 total time=   0.3s
# [CV 1/5; 6/32] START criterion=gini, max_depth=3, n_estimators=200..............
# [CV 1/5; 6/32] END criterion=gini, max_depth=3, n_estimators=200;, score=0.782 total time=   0.8s
# [CV 2/5; 6/32] START criterion=gini, max_depth=3, n_estimators=200..............
# [CV 2/5; 6/32] END criterion=gini, max_depth=3, n_estimators=200;, score=0.797 total time=   0.8s
# [CV 3/5; 6/32] START criterion=gini, max_depth=3, n_estimators=200..............
# [CV 3/5; 6/32] END criterion=gini, max_depth=3, n_estimators=200;, score=0.838 total time=   0.8s
# [CV 4/5; 6/32] START criterion=gini, max_depth=3, n_estimators=200..............
# [CV 4/5; 6/32] END criterion=gini, max_depth=3, n_estimators=200;, score=0.785 total time=   0.8s
# [CV 5/5; 6/32] START criterion=gini, max_depth=3, n_estimators=200..............
# [CV 5/5; 6/32] END criterion=gini, max_depth=3, n_estimators=200;, score=0.785 total time=   0.5s
# [CV 1/5; 7/32] START criterion=gini, max_depth=3, n_estimators=300..............
# [CV 1/5; 7/32] END criterion=gini, max_depth=3, n_estimators=300;, score=0.818 total time=   0.9s
# [CV 2/5; 7/32] START criterion=gini, max_depth=3, n_estimators=300..............
# [CV 2/5; 7/32] END criterion=gini, max_depth=3, n_estimators=300;, score=0.792 total time=   0.9s
# [CV 3/5; 7/32] START criterion=gini, max_depth=3, n_estimators=300..............
# [CV 3/5; 7/32] END criterion=gini, max_depth=3, n_estimators=300;, score=0.840 total time=   0.9s
# [CV 4/5; 7/32] START criterion=gini, max_depth=3, n_estimators=300..............
# [CV 4/5; 7/32] END criterion=gini, max_depth=3, n_estimators=300;, score=0.800 total time=   0.8s
# [CV 5/5; 7/32] START criterion=gini, max_depth=3, n_estimators=300..............
# [CV 5/5; 7/32] END criterion=gini, max_depth=3, n_estimators=300;, score=0.807 total time=   0.8s
# [CV 1/5; 8/32] START criterion=gini, max_depth=3, n_estimators=400..............
# [CV 1/5; 8/32] END criterion=gini, max_depth=3, n_estimators=400;, score=0.785 total time=   1.1s
# [CV 2/5; 8/32] START criterion=gini, max_depth=3, n_estimators=400..............
# [CV 2/5; 8/32] END criterion=gini, max_depth=3, n_estimators=400;, score=0.800 total time=   1.3s
# [CV 3/5; 8/32] START criterion=gini, max_depth=3, n_estimators=400..............
# [CV 3/5; 8/32] END criterion=gini, max_depth=3, n_estimators=400;, score=0.828 total time=   1.1s
# [CV 4/5; 8/32] START criterion=gini, max_depth=3, n_estimators=400..............
# [CV 4/5; 8/32] END criterion=gini, max_depth=3, n_estimators=400;, score=0.807 total time=   1.1s
# [CV 5/5; 8/32] START criterion=gini, max_depth=3, n_estimators=400..............
# [CV 5/5; 8/32] END criterion=gini, max_depth=3, n_estimators=400;, score=0.800 total time=   1.3s
# [CV 1/5; 9/32] START criterion=gini, max_depth=5, n_estimators=100..............
# [CV 1/5; 9/32] END criterion=gini, max_depth=5, n_estimators=100;, score=0.838 total time=   0.5s
# [CV 2/5; 9/32] START criterion=gini, max_depth=5, n_estimators=100..............
# [CV 2/5; 9/32] END criterion=gini, max_depth=5, n_estimators=100;, score=0.823 total time=   0.5s
# [CV 3/5; 9/32] START criterion=gini, max_depth=5, n_estimators=100..............
# [CV 3/5; 9/32] END criterion=gini, max_depth=5, n_estimators=100;, score=0.880 total time=   0.5s
# [CV 4/5; 9/32] START criterion=gini, max_depth=5, n_estimators=100..............
# [CV 4/5; 9/32] END criterion=gini, max_depth=5, n_estimators=100;, score=0.818 total time=   0.4s
# [CV 5/5; 9/32] START criterion=gini, max_depth=5, n_estimators=100..............
# [CV 5/5; 9/32] END criterion=gini, max_depth=5, n_estimators=100;, score=0.823 total time=   0.3s
# [CV 1/5; 10/32] START criterion=gini, max_depth=5, n_estimators=200.............
# [CV 1/5; 10/32] END criterion=gini, max_depth=5, n_estimators=200;, score=0.830 total time=   0.7s
# [CV 2/5; 10/32] START criterion=gini, max_depth=5, n_estimators=200.............
# [CV 2/5; 10/32] END criterion=gini, max_depth=5, n_estimators=200;, score=0.840 total time=   0.6s
# [CV 3/5; 10/32] START criterion=gini, max_depth=5, n_estimators=200.............
# [CV 3/5; 10/32] END criterion=gini, max_depth=5, n_estimators=200;, score=0.875 total time=   0.6s
# [CV 4/5; 10/32] START criterion=gini, max_depth=5, n_estimators=200.............
# [CV 4/5; 10/32] END criterion=gini, max_depth=5, n_estimators=200;, score=0.840 total time=   0.7s
# [CV 5/5; 10/32] START criterion=gini, max_depth=5, n_estimators=200.............
# [CV 5/5; 10/32] END criterion=gini, max_depth=5, n_estimators=200;, score=0.830 total time=   0.6s
# [CV 1/5; 11/32] START criterion=gini, max_depth=5, n_estimators=300.............
# [CV 1/5; 11/32] END criterion=gini, max_depth=5, n_estimators=300;, score=0.838 total time=   0.9s
# [CV 2/5; 11/32] START criterion=gini, max_depth=5, n_estimators=300.............
# [CV 2/5; 11/32] END criterion=gini, max_depth=5, n_estimators=300;, score=0.855 total time=   0.9s
# [CV 3/5; 11/32] START criterion=gini, max_depth=5, n_estimators=300.............
# [CV 3/5; 11/32] END criterion=gini, max_depth=5, n_estimators=300;, score=0.858 total time=   0.9s
# [CV 4/5; 11/32] START criterion=gini, max_depth=5, n_estimators=300.............
# [CV 4/5; 11/32] END criterion=gini, max_depth=5, n_estimators=300;, score=0.840 total time=   1.0s
# [CV 5/5; 11/32] START criterion=gini, max_depth=5, n_estimators=300.............
# [CV 5/5; 11/32] END criterion=gini, max_depth=5, n_estimators=300;, score=0.812 total time=   0.9s
# [CV 1/5; 12/32] START criterion=gini, max_depth=5, n_estimators=400.............
# [CV 1/5; 12/32] END criterion=gini, max_depth=5, n_estimators=400;, score=0.840 total time=   1.3s
# [CV 2/5; 12/32] START criterion=gini, max_depth=5, n_estimators=400.............
# [CV 2/5; 12/32] END criterion=gini, max_depth=5, n_estimators=400;, score=0.848 total time=   1.6s
# [CV 3/5; 12/32] START criterion=gini, max_depth=5, n_estimators=400.............
# [CV 3/5; 12/32] END criterion=gini, max_depth=5, n_estimators=400;, score=0.865 total time=   1.6s
# [CV 4/5; 12/32] START criterion=gini, max_depth=5, n_estimators=400.............
# [CV 4/5; 12/32] END criterion=gini, max_depth=5, n_estimators=400;, score=0.835 total time=   1.2s
# [CV 5/5; 12/32] START criterion=gini, max_depth=5, n_estimators=400.............
# [CV 5/5; 12/32] END criterion=gini, max_depth=5, n_estimators=400;, score=0.815 total time=   1.3s
# [CV 1/5; 13/32] START criterion=gini, max_depth=7, n_estimators=100.............
# [CV 1/5; 13/32] END criterion=gini, max_depth=7, n_estimators=100;, score=0.855 total time=   0.4s
# [CV 2/5; 13/32] START criterion=gini, max_depth=7, n_estimators=100.............
# [CV 2/5; 13/32] END criterion=gini, max_depth=7, n_estimators=100;, score=0.875 total time=   0.3s
# [CV 3/5; 13/32] START criterion=gini, max_depth=7, n_estimators=100.............
# [CV 3/5; 13/32] END criterion=gini, max_depth=7, n_estimators=100;, score=0.880 total time=   0.4s
# [CV 4/5; 13/32] START criterion=gini, max_depth=7, n_estimators=100.............
# [CV 4/5; 13/32] END criterion=gini, max_depth=7, n_estimators=100;, score=0.853 total time=   0.4s
# [CV 5/5; 13/32] START criterion=gini, max_depth=7, n_estimators=100.............
# [CV 5/5; 13/32] END criterion=gini, max_depth=7, n_estimators=100;, score=0.843 total time=   0.4s
# [CV 1/5; 14/32] START criterion=gini, max_depth=7, n_estimators=200.............
# [CV 1/5; 14/32] END criterion=gini, max_depth=7, n_estimators=200;, score=0.860 total time=   0.7s
# [CV 2/5; 14/32] START criterion=gini, max_depth=7, n_estimators=200.............
# [CV 2/5; 14/32] END criterion=gini, max_depth=7, n_estimators=200;, score=0.880 total time=   0.7s
# [CV 3/5; 14/32] START criterion=gini, max_depth=7, n_estimators=200.............
# [CV 3/5; 14/32] END criterion=gini, max_depth=7, n_estimators=200;, score=0.885 total time=   0.7s
# [CV 4/5; 14/32] START criterion=gini, max_depth=7, n_estimators=200.............
# [CV 4/5; 14/32] END criterion=gini, max_depth=7, n_estimators=200;, score=0.855 total time=   0.7s
# [CV 5/5; 14/32] START criterion=gini, max_depth=7, n_estimators=200.............
# [CV 5/5; 14/32] END criterion=gini, max_depth=7, n_estimators=200;, score=0.843 total time=   0.7s
# [CV 1/5; 15/32] START criterion=gini, max_depth=7, n_estimators=300.............
# [CV 1/5; 15/32] END criterion=gini, max_depth=7, n_estimators=300;, score=0.868 total time=   1.1s
# [CV 2/5; 15/32] START criterion=gini, max_depth=7, n_estimators=300.............
# [CV 2/5; 15/32] END criterion=gini, max_depth=7, n_estimators=300;, score=0.870 total time=   1.4s
# [CV 3/5; 15/32] START criterion=gini, max_depth=7, n_estimators=300.............
# [CV 3/5; 15/32] END criterion=gini, max_depth=7, n_estimators=300;, score=0.907 total time=   1.6s
# [CV 4/5; 15/32] START criterion=gini, max_depth=7, n_estimators=300.............
# [CV 4/5; 15/32] END criterion=gini, max_depth=7, n_estimators=300;, score=0.865 total time=   1.1s
# [CV 5/5; 15/32] START criterion=gini, max_depth=7, n_estimators=300.............
# [CV 5/5; 15/32] END criterion=gini, max_depth=7, n_estimators=300;, score=0.855 total time=   1.1s
# [CV 1/5; 16/32] START criterion=gini, max_depth=7, n_estimators=400.............
# [CV 1/5; 16/32] END criterion=gini, max_depth=7, n_estimators=400;, score=0.870 total time=   1.4s
# [CV 2/5; 16/32] START criterion=gini, max_depth=7, n_estimators=400.............
# [CV 2/5; 16/32] END criterion=gini, max_depth=7, n_estimators=400;, score=0.870 total time=   1.4s
# [CV 3/5; 16/32] START criterion=gini, max_depth=7, n_estimators=400.............
# [CV 3/5; 16/32] END criterion=gini, max_depth=7, n_estimators=400;, score=0.885 total time=   1.4s
# [CV 4/5; 16/32] START criterion=gini, max_depth=7, n_estimators=400.............
# [CV 4/5; 16/32] END criterion=gini, max_depth=7, n_estimators=400;, score=0.855 total time=   1.4s
# [CV 5/5; 16/32] START criterion=gini, max_depth=7, n_estimators=400.............
# [CV 5/5; 16/32] END criterion=gini, max_depth=7, n_estimators=400;, score=0.843 total time=   1.4s
# [CV 1/5; 17/32] START criterion=entropy, max_depth=1, n_estimators=100..........
# [CV 1/5; 17/32] END criterion=entropy, max_depth=1, n_estimators=100;, score=0.568 total time=   0.3s
# [CV 2/5; 17/32] START criterion=entropy, max_depth=1, n_estimators=100..........
# [CV 2/5; 17/32] END criterion=entropy, max_depth=1, n_estimators=100;, score=0.517 total time=   0.3s
# [CV 3/5; 17/32] START criterion=entropy, max_depth=1, n_estimators=100..........
# [CV 3/5; 17/32] END criterion=entropy, max_depth=1, n_estimators=100;, score=0.565 total time=   0.2s
# [CV 4/5; 17/32] START criterion=entropy, max_depth=1, n_estimators=100..........
# [CV 4/5; 17/32] END criterion=entropy, max_depth=1, n_estimators=100;, score=0.535 total time=   0.3s
# [CV 5/5; 17/32] START criterion=entropy, max_depth=1, n_estimators=100..........
# [CV 5/5; 17/32] END criterion=entropy, max_depth=1, n_estimators=100;, score=0.557 total time=   0.3s
# [CV 1/5; 18/32] START criterion=entropy, max_depth=1, n_estimators=200..........
# [CV 1/5; 18/32] END criterion=entropy, max_depth=1, n_estimators=200;, score=0.537 total time=   0.7s
# [CV 2/5; 18/32] START criterion=entropy, max_depth=1, n_estimators=200..........
# [CV 2/5; 18/32] END criterion=entropy, max_depth=1, n_estimators=200;, score=0.542 total time=   0.7s
# [CV 3/5; 18/32] START criterion=entropy, max_depth=1, n_estimators=200..........
# [CV 3/5; 18/32] END criterion=entropy, max_depth=1, n_estimators=200;, score=0.552 total time=   0.7s
# [CV 4/5; 18/32] START criterion=entropy, max_depth=1, n_estimators=200..........
# [CV 4/5; 18/32] END criterion=entropy, max_depth=1, n_estimators=200;, score=0.540 total time=   0.5s
# [CV 5/5; 18/32] START criterion=entropy, max_depth=1, n_estimators=200..........
# [CV 5/5; 18/32] END criterion=entropy, max_depth=1, n_estimators=200;, score=0.547 total time=   0.5s
# [CV 1/5; 19/32] START criterion=entropy, max_depth=1, n_estimators=300..........
# [CV 1/5; 19/32] END criterion=entropy, max_depth=1, n_estimators=300;, score=0.588 total time=   0.7s
# [CV 2/5; 19/32] START criterion=entropy, max_depth=1, n_estimators=300..........
# [CV 2/5; 19/32] END criterion=entropy, max_depth=1, n_estimators=300;, score=0.557 total time=   0.7s
# [CV 3/5; 19/32] START criterion=entropy, max_depth=1, n_estimators=300..........
# [CV 3/5; 19/32] END criterion=entropy, max_depth=1, n_estimators=300;, score=0.565 total time=   0.8s
# [CV 4/5; 19/32] START criterion=entropy, max_depth=1, n_estimators=300..........
# [CV 4/5; 19/32] END criterion=entropy, max_depth=1, n_estimators=300;, score=0.568 total time=   0.8s
# [CV 5/5; 19/32] START criterion=entropy, max_depth=1, n_estimators=300..........
# [CV 5/5; 19/32] END criterion=entropy, max_depth=1, n_estimators=300;, score=0.535 total time=   0.7s
# [CV 1/5; 20/32] START criterion=entropy, max_depth=1, n_estimators=400..........
# [CV 1/5; 20/32] END criterion=entropy, max_depth=1, n_estimators=400;, score=0.580 total time=   1.0s
# [CV 2/5; 20/32] START criterion=entropy, max_depth=1, n_estimators=400..........
# [CV 2/5; 20/32] END criterion=entropy, max_depth=1, n_estimators=400;, score=0.557 total time=   1.0s
# [CV 3/5; 20/32] START criterion=entropy, max_depth=1, n_estimators=400..........
# [CV 3/5; 20/32] END criterion=entropy, max_depth=1, n_estimators=400;, score=0.552 total time=   1.0s
# [CV 4/5; 20/32] START criterion=entropy, max_depth=1, n_estimators=400..........
# [CV 4/5; 20/32] END criterion=entropy, max_depth=1, n_estimators=400;, score=0.555 total time=   1.0s
# [CV 5/5; 20/32] START criterion=entropy, max_depth=1, n_estimators=400..........
# [CV 5/5; 20/32] END criterion=entropy, max_depth=1, n_estimators=400;, score=0.535 total time=   1.0s
# [CV 1/5; 21/32] START criterion=entropy, max_depth=3, n_estimators=100..........
# [CV 1/5; 21/32] END criterion=entropy, max_depth=3, n_estimators=100;, score=0.785 total time=   0.5s
# [CV 2/5; 21/32] START criterion=entropy, max_depth=3, n_estimators=100..........
# [CV 2/5; 21/32] END criterion=entropy, max_depth=3, n_estimators=100;, score=0.762 total time=   0.4s
# [CV 3/5; 21/32] START criterion=entropy, max_depth=3, n_estimators=100..........
# [CV 3/5; 21/32] END criterion=entropy, max_depth=3, n_estimators=100;, score=0.818 total time=   0.5s
# [CV 4/5; 21/32] START criterion=entropy, max_depth=3, n_estimators=100..........
# [CV 4/5; 21/32] END criterion=entropy, max_depth=3, n_estimators=100;, score=0.772 total time=   0.4s
# [CV 5/5; 21/32] START criterion=entropy, max_depth=3, n_estimators=100..........
# [CV 5/5; 21/32] END criterion=entropy, max_depth=3, n_estimators=100;, score=0.750 total time=   0.5s
# [CV 1/5; 22/32] START criterion=entropy, max_depth=3, n_estimators=200..........
# [CV 1/5; 22/32] END criterion=entropy, max_depth=3, n_estimators=200;, score=0.795 total time=   0.7s
# [CV 2/5; 22/32] START criterion=entropy, max_depth=3, n_estimators=200..........
# [CV 2/5; 22/32] END criterion=entropy, max_depth=3, n_estimators=200;, score=0.760 total time=   0.6s
# [CV 3/5; 22/32] START criterion=entropy, max_depth=3, n_estimators=200..........
# [CV 3/5; 22/32] END criterion=entropy, max_depth=3, n_estimators=200;, score=0.797 total time=   0.6s
# [CV 4/5; 22/32] START criterion=entropy, max_depth=3, n_estimators=200..........
# [CV 4/5; 22/32] END criterion=entropy, max_depth=3, n_estimators=200;, score=0.810 total time=   0.6s
# [CV 5/5; 22/32] START criterion=entropy, max_depth=3, n_estimators=200..........
# [CV 5/5; 22/32] END criterion=entropy, max_depth=3, n_estimators=200;, score=0.795 total time=   0.6s
# [CV 1/5; 23/32] START criterion=entropy, max_depth=3, n_estimators=300..........
# [CV 1/5; 23/32] END criterion=entropy, max_depth=3, n_estimators=300;, score=0.740 total time=   0.9s
# [CV 2/5; 23/32] START criterion=entropy, max_depth=3, n_estimators=300..........
# [CV 2/5; 23/32] END criterion=entropy, max_depth=3, n_estimators=300;, score=0.765 total time=   0.9s
# [CV 3/5; 23/32] START criterion=entropy, max_depth=3, n_estimators=300..........
# [CV 3/5; 23/32] END criterion=entropy, max_depth=3, n_estimators=300;, score=0.812 total time=   0.9s
# [CV 4/5; 23/32] START criterion=entropy, max_depth=3, n_estimators=300..........
# [CV 4/5; 23/32] END criterion=entropy, max_depth=3, n_estimators=300;, score=0.792 total time=   0.9s
# [CV 5/5; 23/32] START criterion=entropy, max_depth=3, n_estimators=300..........
# [CV 5/5; 23/32] END criterion=entropy, max_depth=3, n_estimators=300;, score=0.752 total time=   0.9s
# [CV 1/5; 24/32] START criterion=entropy, max_depth=3, n_estimators=400..........
# [CV 1/5; 24/32] END criterion=entropy, max_depth=3, n_estimators=400;, score=0.777 total time=   1.2s
# [CV 2/5; 24/32] START criterion=entropy, max_depth=3, n_estimators=400..........
# [CV 2/5; 24/32] END criterion=entropy, max_depth=3, n_estimators=400;, score=0.777 total time=   1.2s
# [CV 3/5; 24/32] START criterion=entropy, max_depth=3, n_estimators=400..........
# [CV 3/5; 24/32] END criterion=entropy, max_depth=3, n_estimators=400;, score=0.800 total time=   1.5s
# [CV 4/5; 24/32] START criterion=entropy, max_depth=3, n_estimators=400..........
# [CV 4/5; 24/32] END criterion=entropy, max_depth=3, n_estimators=400;, score=0.790 total time=   1.6s
# [CV 5/5; 24/32] START criterion=entropy, max_depth=3, n_estimators=400..........
# [CV 5/5; 24/32] END criterion=entropy, max_depth=3, n_estimators=400;, score=0.760 total time=   1.2s
# [CV 1/5; 25/32] START criterion=entropy, max_depth=5, n_estimators=100..........
# [CV 1/5; 25/32] END criterion=entropy, max_depth=5, n_estimators=100;, score=0.828 total time=   0.4s
# [CV 2/5; 25/32] START criterion=entropy, max_depth=5, n_estimators=100..........
# [CV 2/5; 25/32] END criterion=entropy, max_depth=5, n_estimators=100;, score=0.823 total time=   0.4s
# [CV 3/5; 25/32] START criterion=entropy, max_depth=5, n_estimators=100..........
# [CV 3/5; 25/32] END criterion=entropy, max_depth=5, n_estimators=100;, score=0.863 total time=   0.4s
# [CV 4/5; 25/32] START criterion=entropy, max_depth=5, n_estimators=100..........
# [CV 4/5; 25/32] END criterion=entropy, max_depth=5, n_estimators=100;, score=0.843 total time=   0.4s
# [CV 5/5; 25/32] START criterion=entropy, max_depth=5, n_estimators=100..........
# [CV 5/5; 25/32] END criterion=entropy, max_depth=5, n_estimators=100;, score=0.838 total time=   0.4s
# [CV 1/5; 26/32] START criterion=entropy, max_depth=5, n_estimators=200..........
# [CV 1/5; 26/32] END criterion=entropy, max_depth=5, n_estimators=200;, score=0.845 total time=   0.7s
# [CV 2/5; 26/32] START criterion=entropy, max_depth=5, n_estimators=200..........
# [CV 2/5; 26/32] END criterion=entropy, max_depth=5, n_estimators=200;, score=0.830 total time=   0.7s
# [CV 3/5; 26/32] START criterion=entropy, max_depth=5, n_estimators=200..........
# [CV 3/5; 26/32] END criterion=entropy, max_depth=5, n_estimators=200;, score=0.855 total time=   0.7s
# [CV 4/5; 26/32] START criterion=entropy, max_depth=5, n_estimators=200..........
# [CV 4/5; 26/32] END criterion=entropy, max_depth=5, n_estimators=200;, score=0.840 total time=   0.7s
# [CV 5/5; 26/32] START criterion=entropy, max_depth=5, n_estimators=200..........
# [CV 5/5; 26/32] END criterion=entropy, max_depth=5, n_estimators=200;, score=0.850 total time=   0.7s
# [CV 1/5; 27/32] START criterion=entropy, max_depth=5, n_estimators=300..........
# [CV 1/5; 27/32] END criterion=entropy, max_depth=5, n_estimators=300;, score=0.845 total time=   1.1s
# [CV 2/5; 27/32] START criterion=entropy, max_depth=5, n_estimators=300..........
# [CV 2/5; 27/32] END criterion=entropy, max_depth=5, n_estimators=300;, score=0.845 total time=   1.0s
# [CV 3/5; 27/32] START criterion=entropy, max_depth=5, n_estimators=300..........
# [CV 3/5; 27/32] END criterion=entropy, max_depth=5, n_estimators=300;, score=0.863 total time=   1.1s
# [CV 4/5; 27/32] START criterion=entropy, max_depth=5, n_estimators=300..........
# [CV 4/5; 27/32] END criterion=entropy, max_depth=5, n_estimators=300;, score=0.838 total time=   1.6s
# [CV 5/5; 27/32] START criterion=entropy, max_depth=5, n_estimators=300..........
# [CV 5/5; 27/32] END criterion=entropy, max_depth=5, n_estimators=300;, score=0.835 total time=   1.3s
# [CV 1/5; 28/32] START criterion=entropy, max_depth=5, n_estimators=400..........
# [CV 1/5; 28/32] END criterion=entropy, max_depth=5, n_estimators=400;, score=0.838 total time=   1.4s
# [CV 2/5; 28/32] START criterion=entropy, max_depth=5, n_estimators=400..........
# [CV 2/5; 28/32] END criterion=entropy, max_depth=5, n_estimators=400;, score=0.843 total time=   1.4s
# [CV 3/5; 28/32] START criterion=entropy, max_depth=5, n_estimators=400..........
# [CV 3/5; 28/32] END criterion=entropy, max_depth=5, n_estimators=400;, score=0.850 total time=   1.4s
# [CV 4/5; 28/32] START criterion=entropy, max_depth=5, n_estimators=400..........
# [CV 4/5; 28/32] END criterion=entropy, max_depth=5, n_estimators=400;, score=0.840 total time=   1.4s
# [CV 5/5; 28/32] START criterion=entropy, max_depth=5, n_estimators=400..........
# [CV 5/5; 28/32] END criterion=entropy, max_depth=5, n_estimators=400;, score=0.843 total time=   1.4s
# [CV 1/5; 29/32] START criterion=entropy, max_depth=7, n_estimators=100..........
# [CV 1/5; 29/32] END criterion=entropy, max_depth=7, n_estimators=100;, score=0.853 total time=   0.4s
# [CV 2/5; 29/32] START criterion=entropy, max_depth=7, n_estimators=100..........
# [CV 2/5; 29/32] END criterion=entropy, max_depth=7, n_estimators=100;, score=0.850 total time=   0.4s
# [CV 3/5; 29/32] START criterion=entropy, max_depth=7, n_estimators=100..........
# [CV 3/5; 29/32] END criterion=entropy, max_depth=7, n_estimators=100;, score=0.887 total time=   0.4s
# [CV 4/5; 29/32] START criterion=entropy, max_depth=7, n_estimators=100..........
# [CV 4/5; 29/32] END criterion=entropy, max_depth=7, n_estimators=100;, score=0.855 total time=   0.4s
# [CV 5/5; 29/32] START criterion=entropy, max_depth=7, n_estimators=100..........
# [CV 5/5; 29/32] END criterion=entropy, max_depth=7, n_estimators=100;, score=0.863 total time=   0.5s
# [CV 1/5; 30/32] START criterion=entropy, max_depth=7, n_estimators=200..........
# [CV 1/5; 30/32] END criterion=entropy, max_depth=7, n_estimators=200;, score=0.860 total time=   1.5s
# [CV 2/5; 30/32] START criterion=entropy, max_depth=7, n_estimators=200..........
# [CV 2/5; 30/32] END criterion=entropy, max_depth=7, n_estimators=200;, score=0.865 total time=   1.5s
# [CV 3/5; 30/32] START criterion=entropy, max_depth=7, n_estimators=200..........
# [CV 3/5; 30/32] END criterion=entropy, max_depth=7, n_estimators=200;, score=0.892 total time=   1.4s
# [CV 4/5; 30/32] START criterion=entropy, max_depth=7, n_estimators=200..........
# [CV 4/5; 30/32] END criterion=entropy, max_depth=7, n_estimators=200;, score=0.863 total time=   0.8s
# [CV 5/5; 30/32] START criterion=entropy, max_depth=7, n_estimators=200..........
# [CV 5/5; 30/32] END criterion=entropy, max_depth=7, n_estimators=200;, score=0.858 total time=   0.8s
# [CV 1/5; 31/32] START criterion=entropy, max_depth=7, n_estimators=300..........
# [CV 1/5; 31/32] END criterion=entropy, max_depth=7, n_estimators=300;, score=0.863 total time=   1.2s
# [CV 2/5; 31/32] START criterion=entropy, max_depth=7, n_estimators=300..........
# [CV 2/5; 31/32] END criterion=entropy, max_depth=7, n_estimators=300;, score=0.877 total time=   1.2s
# [CV 3/5; 31/32] START criterion=entropy, max_depth=7, n_estimators=300..........
# [CV 3/5; 31/32] END criterion=entropy, max_depth=7, n_estimators=300;, score=0.897 total time=   1.2s
# [CV 4/5; 31/32] START criterion=entropy, max_depth=7, n_estimators=300..........
# [CV 4/5; 31/32] END criterion=entropy, max_depth=7, n_estimators=300;, score=0.845 total time=   1.2s
# [CV 5/5; 31/32] START criterion=entropy, max_depth=7, n_estimators=300..........
# [CV 5/5; 31/32] END criterion=entropy, max_depth=7, n_estimators=300;, score=0.855 total time=   1.2s
# [CV 1/5; 32/32] START criterion=entropy, max_depth=7, n_estimators=400..........
# [CV 1/5; 32/32] END criterion=entropy, max_depth=7, n_estimators=400;, score=0.865 total time=   1.6s
# [CV 2/5; 32/32] START criterion=entropy, max_depth=7, n_estimators=400..........
# [CV 2/5; 32/32] END criterion=entropy, max_depth=7, n_estimators=400;, score=0.870 total time=   2.2s
# [CV 3/5; 32/32] START criterion=entropy, max_depth=7, n_estimators=400..........
# [CV 3/5; 32/32] END criterion=entropy, max_depth=7, n_estimators=400;, score=0.897 total time=   1.9s
# [CV 4/5; 32/32] START criterion=entropy, max_depth=7, n_estimators=400..........
# [CV 4/5; 32/32] END criterion=entropy, max_depth=7, n_estimators=400;, score=0.865 total time=   1.6s
# [CV 5/5; 32/32] START criterion=entropy, max_depth=7, n_estimators=400..........
# [CV 5/5; 32/32] END criterion=entropy, max_depth=7, n_estimators=400;, score=0.853 total time=   1.6s

# %%
model.best_score_
# Out:
# 0.873

# %%
model.best_estimator_
# Out:
# RandomForestClassifier(max_depth=7, n_estimators=300, n_jobs=-1)

# %%
model.best_estimator_.get_params()
# Out:
# {'bootstrap': True,
#  'ccp_alpha': 0.0,
#  'class_weight': None,
#  'criterion': 'gini',
#  'max_depth': 7,
#  'max_features': 'sqrt',
#  'max_leaf_nodes': None,
#  'max_samples': None,
#  'min_impurity_decrease': 0.0,
#  'min_samples_leaf': 1,
#  'min_samples_split': 2,
#  'min_weight_fraction_leaf': 0.0,
#  'n_estimators': 300,
#  'n_jobs': -1,
#  'oob_score': False,
#  'random_state': None,
#  'verbose': 0,
#  'warm_start': False}

# %%
#Random Search CV
if __name__=='__main__':
  df = pd.read_csv('https://raw.githubusercontent.com/Nithya-Vasudevan/Mobile-Price-Classification/master/train.csv')
  X = df.drop('price_range', axis=1).values
  y = df.price_range.values

  classifier = ensemble.RandomForestClassifier(n_jobs=-1)
  param_grid = {
      'n_estimators':np.arange(100,1500,100),
      'max_depth':np.arange(1,20),
      'criterion':['gini','entropy'],

  }
  model = model_selection.RandomizedSearchCV(
      estimator=classifier,
      param_distributions = param_grid,
      n_iter=10,
      scoring = 'accuracy',
      verbose=10,
      n_jobs = 1,
      cv=5
  )

  model.fit(X,y)
# Out:
# Fitting 5 folds for each of 10 candidates, totalling 50 fits
# [CV 1/5; 1/10] START criterion=entropy, max_depth=5, n_estimators=1400..........
# [CV 1/5; 1/10] END criterion=entropy, max_depth=5, n_estimators=1400;, score=0.843 total time=   4.8s
# [CV 2/5; 1/10] START criterion=entropy, max_depth=5, n_estimators=1400..........
# [CV 2/5; 1/10] END criterion=entropy, max_depth=5, n_estimators=1400;, score=0.840 total time=   5.7s
# [CV 3/5; 1/10] START criterion=entropy, max_depth=5, n_estimators=1400..........
# [CV 3/5; 1/10] END criterion=entropy, max_depth=5, n_estimators=1400;, score=0.868 total time=   4.9s
# [CV 4/5; 1/10] START criterion=entropy, max_depth=5, n_estimators=1400..........
# [CV 4/5; 1/10] END criterion=entropy, max_depth=5, n_estimators=1400;, score=0.838 total time=   5.2s
# [CV 5/5; 1/10] START criterion=entropy, max_depth=5, n_estimators=1400..........
# [CV 5/5; 1/10] END criterion=entropy, max_depth=5, n_estimators=1400;, score=0.848 total time=   5.7s
# [CV 1/5; 2/10] START criterion=gini, max_depth=12, n_estimators=600.............
# [CV 1/5; 2/10] END criterion=gini, max_depth=12, n_estimators=600;, score=0.875 total time=   2.5s
# [CV 2/5; 2/10] START criterion=gini, max_depth=12, n_estimators=600.............
# [CV 2/5; 2/10] END criterion=gini, max_depth=12, n_estimators=600;, score=0.882 total time=   2.5s
# [CV 3/5; 2/10] START criterion=gini, max_depth=12, n_estimators=600.............
# [CV 3/5; 2/10] END criterion=gini, max_depth=12, n_estimators=600;, score=0.892 total time=   3.2s
# [CV 4/5; 2/10] START criterion=gini, max_depth=12, n_estimators=600.............
# [CV 4/5; 2/10] END criterion=gini, max_depth=12, n_estimators=600;, score=0.870 total time=   4.2s
# [CV 5/5; 2/10] START criterion=gini, max_depth=12, n_estimators=600.............
# [CV 5/5; 2/10] END criterion=gini, max_depth=12, n_estimators=600;, score=0.870 total time=   3.1s
# [CV 1/5; 3/10] START criterion=gini, max_depth=4, n_estimators=800..............
# [CV 1/5; 3/10] END criterion=gini, max_depth=4, n_estimators=800;, score=0.805 total time=   2.4s
# [CV 2/5; 3/10] START criterion=gini, max_depth=4, n_estimators=800..............
# [CV 2/5; 3/10] END criterion=gini, max_depth=4, n_estimators=800;, score=0.830 total time=   3.1s
# [CV 3/5; 3/10] START criterion=gini, max_depth=4, n_estimators=800..............
# [CV 3/5; 3/10] END criterion=gini, max_depth=4, n_estimators=800;, score=0.835 total time=   2.4s
# [CV 4/5; 3/10] START criterion=gini, max_depth=4, n_estimators=800..............
# [CV 4/5; 3/10] END criterion=gini, max_depth=4, n_estimators=800;, score=0.807 total time=   2.4s
# [CV 5/5; 3/10] START criterion=gini, max_depth=4, n_estimators=800..............
# [CV 5/5; 3/10] END criterion=gini, max_depth=4, n_estimators=800;, score=0.810 total time=   2.4s
# [CV 1/5; 4/10] START criterion=gini, max_depth=7, n_estimators=500..............
# [CV 1/5; 4/10] END criterion=gini, max_depth=7, n_estimators=500;, score=0.863 total time=   1.7s
# [CV 2/5; 4/10] START criterion=gini, max_depth=7, n_estimators=500..............
# [CV 2/5; 4/10] END criterion=gini, max_depth=7, n_estimators=500;, score=0.865 total time=   2.1s
# [CV 3/5; 4/10] START criterion=gini, max_depth=7, n_estimators=500..............
# [CV 3/5; 4/10] END criterion=gini, max_depth=7, n_estimators=500;, score=0.882 total time=   2.2s
# [CV 4/5; 4/10] START criterion=gini, max_depth=7, n_estimators=500..............
# [CV 4/5; 4/10] END criterion=gini, max_depth=7, n_estimators=500;, score=0.858 total time=   1.7s
# [CV 5/5; 4/10] START criterion=gini, max_depth=7, n_estimators=500..............
# [CV 5/5; 4/10] END criterion=gini, max_depth=7, n_estimators=500;, score=0.840 total time=   1.8s
# [CV 1/5; 5/10] START criterion=entropy, max_depth=19, n_estimators=1300.........
# [CV 1/5; 5/10] END criterion=entropy, max_depth=19, n_estimators=1300;, score=0.890 total time=   6.6s
# [CV 2/5; 5/10] START criterion=entropy, max_depth=19, n_estimators=1300.........
# [CV 2/5; 5/10] END criterion=entropy, max_depth=19, n_estimators=1300;, score=0.900 total time=   6.8s
# [CV 3/5; 5/10] START criterion=entropy, max_depth=19, n_estimators=1300.........
# [CV 3/5; 5/10] END criterion=entropy, max_depth=19, n_estimators=1300;, score=0.907 total time=   7.3s
# [CV 4/5; 5/10] START criterion=entropy, max_depth=19, n_estimators=1300.........
# [CV 4/5; 5/10] END criterion=entropy, max_depth=19, n_estimators=1300;, score=0.868 total time=   6.2s
# [CV 5/5; 5/10] START criterion=entropy, max_depth=19, n_estimators=1300.........
# [CV 5/5; 5/10] END criterion=entropy, max_depth=19, n_estimators=1300;, score=0.875 total time=   7.3s
# [CV 1/5; 6/10] START criterion=gini, max_depth=6, n_estimators=1200.............
# [CV 1/5; 6/10] END criterion=gini, max_depth=6, n_estimators=1200;, score=0.853 total time=   4.0s
# [CV 2/5; 6/10] START criterion=gini, max_depth=6, n_estimators=1200.............
# [CV 2/5; 6/10] END criterion=gini, max_depth=6, n_estimators=1200;, score=0.865 total time=   4.0s
# [CV 3/5; 6/10] START criterion=gini, max_depth=6, n_estimators=1200.............
# [CV 3/5; 6/10] END criterion=gini, max_depth=6, n_estimators=1200;, score=0.887 total time=   4.8s
# [CV 4/5; 6/10] START criterion=gini, max_depth=6, n_estimators=1200.............
# [CV 4/5; 6/10] END criterion=gini, max_depth=6, n_estimators=1200;, score=0.850 total time=   4.0s
# [CV 5/5; 6/10] START criterion=gini, max_depth=6, n_estimators=1200.............
# [CV 5/5; 6/10] END criterion=gini, max_depth=6, n_estimators=1200;, score=0.830 total time=   4.1s
# [CV 1/5; 7/10] START criterion=entropy, max_depth=10, n_estimators=400..........
# [CV 1/5; 7/10] END criterion=entropy, max_depth=10, n_estimators=400;, score=0.882 total time=   2.9s
# [CV 2/5; 7/10] START criterion=entropy, max_depth=10, n_estimators=400..........
# [CV 2/5; 7/10] END criterion=entropy, max_depth=10, n_estimators=400;, score=0.885 total time=   1.9s
# [CV 3/5; 7/10] START criterion=entropy, max_depth=10, n_estimators=400..........
# [CV 3/5; 7/10] END criterion=entropy, max_depth=10, n_estimators=400;, score=0.902 total time=   1.8s
# [CV 4/5; 7/10] START criterion=entropy, max_depth=10, n_estimators=400..........
# [CV 4/5; 7/10] END criterion=entropy, max_depth=10, n_estimators=400;, score=0.855 total time=   1.9s
# [CV 5/5; 7/10] START criterion=entropy, max_depth=10, n_estimators=400..........
# [CV 5/5; 7/10] END criterion=entropy, max_depth=10, n_estimators=400;, score=0.877 total time=   1.9s
# [CV 1/5; 8/10] START criterion=entropy, max_depth=3, n_estimators=600...........
# [CV 1/5; 8/10] END criterion=entropy, max_depth=3, n_estimators=600;, score=0.792 total time=   1.8s
# [CV 2/5; 8/10] START criterion=entropy, max_depth=3, n_estimators=600...........
# [CV 2/5; 8/10] END criterion=entropy, max_depth=3, n_estimators=600;, score=0.772 total time=   2.3s
# [CV 3/5; 8/10] START criterion=entropy, max_depth=3, n_estimators=600...........
# [CV 3/5; 8/10] END criterion=entropy, max_depth=3, n_estimators=600;, score=0.775 total time=   2.0s
# [CV 4/5; 8/10] START criterion=entropy, max_depth=3, n_estimators=600...........
# [CV 4/5; 8/10] END criterion=entropy, max_depth=3, n_estimators=600;, score=0.762 total time=   1.8s
# [CV 5/5; 8/10] START criterion=entropy, max_depth=3, n_estimators=600...........
# [CV 5/5; 8/10] END criterion=entropy, max_depth=3, n_estimators=600;, score=0.735 total time=   1.8s
# [CV 1/5; 9/10] START criterion=entropy, max_depth=5, n_estimators=100...........
# [CV 1/5; 9/10] END criterion=entropy, max_depth=5, n_estimators=100;, score=0.812 total time=   0.4s
# [CV 2/5; 9/10] START criterion=entropy, max_depth=5, n_estimators=100...........
# [CV 2/5; 9/10] END criterion=entropy, max_depth=5, n_estimators=100;, score=0.828 total time=   0.4s
# [CV 3/5; 9/10] START criterion=entropy, max_depth=5, n_estimators=100...........
# [CV 3/5; 9/10] END criterion=entropy, max_depth=5, n_estimators=100;, score=0.840 total time=   0.4s
# [CV 4/5; 9/10] START criterion=entropy, max_depth=5, n_estimators=100...........
# [CV 4/5; 9/10] END criterion=entropy, max_depth=5, n_estimators=100;, score=0.823 total time=   0.4s
# [CV 5/5; 9/10] START criterion=entropy, max_depth=5, n_estimators=100...........
# [CV 5/5; 9/10] END criterion=entropy, max_depth=5, n_estimators=100;, score=0.828 total time=   0.4s
# [CV 1/5; 10/10] START criterion=gini, max_depth=12, n_estimators=500............
# [CV 1/5; 10/10] END criterion=gini, max_depth=12, n_estimators=500;, score=0.890 total time=   2.1s
# [CV 2/5; 10/10] START criterion=gini, max_depth=12, n_estimators=500............
# [CV 2/5; 10/10] END criterion=gini, max_depth=12, n_estimators=500;, score=0.882 total time=   2.5s
# [CV 3/5; 10/10] START criterion=gini, max_depth=12, n_estimators=500............
# [CV 3/5; 10/10] END criterion=gini, max_depth=12, n_estimators=500;, score=0.885 total time=   2.5s
# [CV 4/5; 10/10] START criterion=gini, max_depth=12, n_estimators=500............
# [CV 4/5; 10/10] END criterion=gini, max_depth=12, n_estimators=500;, score=0.868 total time=   2.1s
# [CV 5/5; 10/10] START criterion=gini, max_depth=12, n_estimators=500............
# [CV 5/5; 10/10] END criterion=gini, max_depth=12, n_estimators=500;, score=0.875 total time=   2.1s

# %%
model.best_estimator_.get_params()
# Out:
# {'bootstrap': True,
#  'ccp_alpha': 0.0,
#  'class_weight': None,
#  'criterion': 'entropy',
#  'max_depth': 19,
#  'max_features': 'sqrt',
#  'max_leaf_nodes': None,
#  'max_samples': None,
#  'min_impurity_decrease': 0.0,
#  'min_samples_leaf': 1,
#  'min_samples_split': 2,
#  'min_weight_fraction_leaf': 0.0,
#  'n_estimators': 1300,
#  'n_jobs': -1,
#  'oob_score': False,
#  'random_state': None,
#  'verbose': 0,
#  'warm_start': False}

# %%
model.best_score_
# Out:
# 0.8879999999999999

# %%
from sklearn import preprocessing
from sklearn import decomposition
from sklearn import pipeline

# %%
#using pipeline
#Random Search CV
if __name__=='__main__':
  df = pd.read_csv('https://raw.githubusercontent.com/Nithya-Vasudevan/Mobile-Price-Classification/master/train.csv')
  X = df.drop('price_range', axis=1).values
  y = df.price_range.values


  scl = preprocessing.StandardScaler()
  pca = decomposition.PCA()
  rf = ensemble.RandomForestClassifier(n_jobs=-1)

  classifier = pipeline.Pipeline([
      ('scaling',scl),
      ('pca', pca),
      ('rf',rf)
  ])
  param_grid = {
      "pca__n_components":np.arange(5,10),
      'rf__n_estimators':np.arange(100,1500,100),
      'rf__max_depth':np.arange(1,20),
      'rf__criterion':['gini','entropy'],

  }
  model = model_selection.RandomizedSearchCV(
      estimator=classifier,
      param_distributions = param_grid,
      n_iter=10,
      scoring = 'accuracy',
      verbose=10,
      n_jobs = 1,
      cv=5
  )

  model.fit(X,y)
  print(model.best_score_)
  print(model.best_estimator_.get_params())
# Out:
# Fitting 5 folds for each of 10 candidates, totalling 50 fits
# [CV 1/5; 1/10] START pca__n_components=7, rf__criterion=gini, rf__max_depth=13, rf__n_estimators=1100
# [CV 1/5; 1/10] END pca__n_components=7, rf__criterion=gini, rf__max_depth=13, rf__n_estimators=1100;, score=0.395 total time=   5.1s
# [CV 2/5; 1/10] START pca__n_components=7, rf__criterion=gini, rf__max_depth=13, rf__n_estimators=1100
# [CV 2/5; 1/10] END pca__n_components=7, rf__criterion=gini, rf__max_depth=13, rf__n_estimators=1100;, score=0.407 total time=   5.8s
# [CV 3/5; 1/10] START pca__n_components=7, rf__criterion=gini, rf__max_depth=13, rf__n_estimators=1100
# [CV 3/5; 1/10] END pca__n_components=7, rf__criterion=gini, rf__max_depth=13, rf__n_estimators=1100;, score=0.365 total time=   4.9s
# [CV 4/5; 1/10] START pca__n_components=7, rf__criterion=gini, rf__max_depth=13, rf__n_estimators=1100
# [CV 4/5; 1/10] END pca__n_components=7, rf__criterion=gini, rf__max_depth=13, rf__n_estimators=1100;, score=0.425 total time=   4.9s
# [CV 5/5; 1/10] START pca__n_components=7, rf__criterion=gini, rf__max_depth=13, rf__n_estimators=1100
# [CV 5/5; 1/10] END pca__n_components=7, rf__criterion=gini, rf__max_depth=13, rf__n_estimators=1100;, score=0.430 total time=   5.8s
# [CV 1/5; 2/10] START pca__n_components=7, rf__criterion=gini, rf__max_depth=11, rf__n_estimators=1300
# [CV 1/5; 2/10] END pca__n_components=7, rf__criterion=gini, rf__max_depth=11, rf__n_estimators=1300;, score=0.405 total time=   5.5s
# [CV 2/5; 2/10] START pca__n_components=7, rf__criterion=gini, rf__max_depth=11, rf__n_estimators=1300
# [CV 2/5; 2/10] END pca__n_components=7, rf__criterion=gini, rf__max_depth=11, rf__n_estimators=1300;, score=0.407 total time=   6.5s
# [CV 3/5; 2/10] START pca__n_components=7, rf__criterion=gini, rf__max_depth=11, rf__n_estimators=1300
# [CV 3/5; 2/10] END pca__n_components=7, rf__criterion=gini, rf__max_depth=11, rf__n_estimators=1300;, score=0.352 total time=   5.5s
# [CV 4/5; 2/10] START pca__n_components=7, rf__criterion=gini, rf__max_depth=11, rf__n_estimators=1300
# [CV 4/5; 2/10] END pca__n_components=7, rf__criterion=gini, rf__max_depth=11, rf__n_estimators=1300;, score=0.417 total time=   6.5s
# [CV 5/5; 2/10] START pca__n_components=7, rf__criterion=gini, rf__max_depth=11, rf__n_estimators=1300
# [CV 5/5; 2/10] END pca__n_components=7, rf__criterion=gini, rf__max_depth=11, rf__n_estimators=1300;, score=0.420 total time=   5.6s
# [CV 1/5; 3/10] START pca__n_components=5, rf__criterion=gini, rf__max_depth=10, rf__n_estimators=800
# [CV 1/5; 3/10] END pca__n_components=5, rf__criterion=gini, rf__max_depth=10, rf__n_estimators=800;, score=0.302 total time=   4.2s
# [CV 2/5; 3/10] START pca__n_components=5, rf__criterion=gini, rf__max_depth=10, rf__n_estimators=800
# [CV 2/5; 3/10] END pca__n_components=5, rf__criterion=gini, rf__max_depth=10, rf__n_estimators=800;, score=0.383 total time=   3.4s
# [CV 3/5; 3/10] START pca__n_components=5, rf__criterion=gini, rf__max_depth=10, rf__n_estimators=800
# [CV 3/5; 3/10] END pca__n_components=5, rf__criterion=gini, rf__max_depth=10, rf__n_estimators=800;, score=0.300 total time=   3.3s
# [CV 4/5; 3/10] START pca__n_components=5, rf__criterion=gini, rf__max_depth=10, rf__n_estimators=800
# [CV 4/5; 3/10] END pca__n_components=5, rf__criterion=gini, rf__max_depth=10, rf__n_estimators=800;, score=0.307 total time=   3.4s
# [CV 5/5; 3/10] START pca__n_components=5, rf__criterion=gini, rf__max_depth=10, rf__n_estimators=800
# [CV 5/5; 3/10] END pca__n_components=5, rf__criterion=gini, rf__max_depth=10, rf__n_estimators=800;, score=0.260 total time=   4.2s
# [CV 1/5; 4/10] START pca__n_components=5, rf__criterion=gini, rf__max_depth=17, rf__n_estimators=800
# [CV 1/5; 4/10] END pca__n_components=5, rf__criterion=gini, rf__max_depth=17, rf__n_estimators=800;, score=0.323 total time=   3.9s
# [CV 2/5; 4/10] START pca__n_components=5, rf__criterion=gini, rf__max_depth=17, rf__n_estimators=800
# [CV 2/5; 4/10] END pca__n_components=5, rf__criterion=gini, rf__max_depth=17, rf__n_estimators=800;, score=0.295 total time=   4.2s
# [CV 3/5; 4/10] START pca__n_components=5, rf__criterion=gini, rf__max_depth=17, rf__n_estimators=800
# [CV 3/5; 4/10] END pca__n_components=5, rf__criterion=gini, rf__max_depth=17, rf__n_estimators=800;, score=0.270 total time=   4.8s
# [CV 4/5; 4/10] START pca__n_components=5, rf__criterion=gini, rf__max_depth=17, rf__n_estimators=800
# [CV 4/5; 4/10] END pca__n_components=5, rf__criterion=gini, rf__max_depth=17, rf__n_estimators=800;, score=0.310 total time=   4.2s
# [CV 5/5; 4/10] START pca__n_components=5, rf__criterion=gini, rf__max_depth=17, rf__n_estimators=800
# [CV 5/5; 4/10] END pca__n_components=5, rf__criterion=gini, rf__max_depth=17, rf__n_estimators=800;, score=0.287 total time=   3.9s
# [CV 1/5; 5/10] START pca__n_components=7, rf__criterion=entropy, rf__max_depth=1, rf__n_estimators=1000
# [CV 1/5; 5/10] END pca__n_components=7, rf__criterion=entropy, rf__max_depth=1, rf__n_estimators=1000;, score=0.380 total time=   3.4s
# [CV 2/5; 5/10] START pca__n_components=7, rf__criterion=entropy, rf__max_depth=1, rf__n_estimators=1000
# [CV 2/5; 5/10] END pca__n_components=7, rf__criterion=entropy, rf__max_depth=1, rf__n_estimators=1000;, score=0.393 total time=   3.9s
# [CV 3/5; 5/10] START pca__n_components=7, rf__criterion=entropy, rf__max_depth=1, rf__n_estimators=1000
# [CV 3/5; 5/10] END pca__n_components=7, rf__criterion=entropy, rf__max_depth=1, rf__n_estimators=1000;, score=0.385 total time=   2.7s
# [CV 4/5; 5/10] START pca__n_components=7, rf__criterion=entropy, rf__max_depth=1, rf__n_estimators=1000
# [CV 4/5; 5/10] END pca__n_components=7, rf__criterion=entropy, rf__max_depth=1, rf__n_estimators=1000;, score=0.380 total time=   2.7s
# [CV 5/5; 5/10] START pca__n_components=7, rf__criterion=entropy, rf__max_depth=1, rf__n_estimators=1000
# [CV 5/5; 5/10] END pca__n_components=7, rf__criterion=entropy, rf__max_depth=1, rf__n_estimators=1000;, score=0.407 total time=   3.3s
# [CV 1/5; 6/10] START pca__n_components=5, rf__criterion=gini, rf__max_depth=15, rf__n_estimators=500
# [CV 1/5; 6/10] END pca__n_components=5, rf__criterion=gini, rf__max_depth=15, rf__n_estimators=500;, score=0.282 total time=   2.3s
# [CV 2/5; 6/10] START pca__n_components=5, rf__criterion=gini, rf__max_depth=15, rf__n_estimators=500
# [CV 2/5; 6/10] END pca__n_components=5, rf__criterion=gini, rf__max_depth=15, rf__n_estimators=500;, score=0.350 total time=   2.4s
# [CV 3/5; 6/10] START pca__n_components=5, rf__criterion=gini, rf__max_depth=15, rf__n_estimators=500
# [CV 3/5; 6/10] END pca__n_components=5, rf__criterion=gini, rf__max_depth=15, rf__n_estimators=500;, score=0.280 total time=   2.4s
# [CV 4/5; 6/10] START pca__n_components=5, rf__criterion=gini, rf__max_depth=15, rf__n_estimators=500
# [CV 4/5; 6/10] END pca__n_components=5, rf__criterion=gini, rf__max_depth=15, rf__n_estimators=500;, score=0.370 total time=   3.0s
# [CV 5/5; 6/10] START pca__n_components=5, rf__criterion=gini, rf__max_depth=15, rf__n_estimators=500
# [CV 5/5; 6/10] END pca__n_components=5, rf__criterion=gini, rf__max_depth=15, rf__n_estimators=500;, score=0.263 total time=   2.7s
# [CV 1/5; 7/10] START pca__n_components=9, rf__criterion=entropy, rf__max_depth=11, rf__n_estimators=700
# [CV 1/5; 7/10] END pca__n_components=9, rf__criterion=entropy, rf__max_depth=11, rf__n_estimators=700;, score=0.410 total time=   5.2s
# [CV 2/5; 7/10] START pca__n_components=9, rf__criterion=entropy, rf__max_depth=11, rf__n_estimators=700
# [CV 2/5; 7/10] END pca__n_components=9, rf__criterion=entropy, rf__max_depth=11, rf__n_estimators=700;, score=0.472 total time=   6.1s
# [CV 3/5; 7/10] START pca__n_components=9, rf__criterion=entropy, rf__max_depth=11, rf__n_estimators=700
# [CV 3/5; 7/10] END pca__n_components=9, rf__criterion=entropy, rf__max_depth=11, rf__n_estimators=700;, score=0.475 total time=   5.0s
# [CV 4/5; 7/10] START pca__n_components=9, rf__criterion=entropy, rf__max_depth=11, rf__n_estimators=700
# [CV 4/5; 7/10] END pca__n_components=9, rf__criterion=entropy, rf__max_depth=11, rf__n_estimators=700;, score=0.507 total time=   5.1s
# [CV 5/5; 7/10] START pca__n_components=9, rf__criterion=entropy, rf__max_depth=11, rf__n_estimators=700
# [CV 5/5; 7/10] END pca__n_components=9, rf__criterion=entropy, rf__max_depth=11, rf__n_estimators=700;, score=0.415 total time=   5.9s
# [CV 1/5; 8/10] START pca__n_components=9, rf__criterion=entropy, rf__max_depth=19, rf__n_estimators=300
# [CV 1/5; 8/10] END pca__n_components=9, rf__criterion=entropy, rf__max_depth=19, rf__n_estimators=300;, score=0.407 total time=   3.4s
# [CV 2/5; 8/10] START pca__n_components=9, rf__criterion=entropy, rf__max_depth=19, rf__n_estimators=300
# [CV 2/5; 8/10] END pca__n_components=9, rf__criterion=entropy, rf__max_depth=19, rf__n_estimators=300;, score=0.443 total time=   2.3s
# [CV 3/5; 8/10] START pca__n_components=9, rf__criterion=entropy, rf__max_depth=19, rf__n_estimators=300
# [CV 3/5; 8/10] END pca__n_components=9, rf__criterion=entropy, rf__max_depth=19, rf__n_estimators=300;, score=0.468 total time=   3.4s
# [CV 4/5; 8/10] START pca__n_components=9, rf__criterion=entropy, rf__max_depth=19, rf__n_estimators=300
# [CV 4/5; 8/10] END pca__n_components=9, rf__criterion=entropy, rf__max_depth=19, rf__n_estimators=300;, score=0.505 total time=   2.3s
# [CV 5/5; 8/10] START pca__n_components=9, rf__criterion=entropy, rf__max_depth=19, rf__n_estimators=300
# [CV 5/5; 8/10] END pca__n_components=9, rf__criterion=entropy, rf__max_depth=19, rf__n_estimators=300;, score=0.407 total time=   2.4s
# [CV 1/5; 9/10] START pca__n_components=6, rf__criterion=entropy, rf__max_depth=19, rf__n_estimators=1400
# [CV 1/5; 9/10] END pca__n_components=6, rf__criterion=entropy, rf__max_depth=19, rf__n_estimators=1400;, score=0.365 total time=  10.1s
# [CV 2/5; 9/10] START pca__n_components=6, rf__criterion=entropy, rf__max_depth=19, rf__n_estimators=1400
# [CV 2/5; 9/10] END pca__n_components=6, rf__criterion=entropy, rf__max_depth=19, rf__n_estimators=1400;, score=0.410 total time=   9.8s
# [CV 3/5; 9/10] START pca__n_components=6, rf__criterion=entropy, rf__max_depth=19, rf__n_estimators=1400
# [CV 3/5; 9/10] END pca__n_components=6, rf__criterion=entropy, rf__max_depth=19, rf__n_estimators=1400;, score=0.345 total time=   8.9s
# [CV 4/5; 9/10] START pca__n_components=6, rf__criterion=entropy, rf__max_depth=19, rf__n_estimators=1400
# [CV 4/5; 9/10] END pca__n_components=6, rf__criterion=entropy, rf__max_depth=19, rf__n_estimators=1400;, score=0.388 total time=  10.2s
# [CV 5/5; 9/10] START pca__n_components=6, rf__criterion=entropy, rf__max_depth=19, rf__n_estimators=1400
# [CV 5/5; 9/10] END pca__n_components=6, rf__criterion=entropy, rf__max_depth=19, rf__n_estimators=1400;, score=0.292 total time=  10.3s
# [CV 1/5; 10/10] START pca__n_components=7, rf__criterion=entropy, rf__max_depth=6, rf__n_estimators=1400
# [CV 1/5; 10/10] END pca__n_components=7, rf__criterion=entropy, rf__max_depth=6, rf__n_estimators=1400;, score=0.407 total time=   6.6s
# [CV 2/5; 10/10] START pca__n_components=7, rf__criterion=entropy, rf__max_depth=6, rf__n_estimators=1400
# [CV 2/5; 10/10] END pca__n_components=7, rf__criterion=entropy, rf__max_depth=6, rf__n_estimators=1400;, score=0.412 total time=   6.9s
# [CV 3/5; 10/10] START pca__n_components=7, rf__criterion=entropy, rf__max_depth=6, rf__n_estimators=1400
# [CV 3/5; 10/10] END pca__n_components=7, rf__criterion=entropy, rf__max_depth=6, rf__n_estimators=1400;, score=0.385 total time=   7.2s
# [CV 4/5; 10/10] START pca__n_components=7, rf__criterion=entropy, rf__max_depth=6, rf__n_estimators=1400
# [CV 4/5; 10/10] END pca__n_components=7, rf__criterion=entropy, rf__max_depth=6, rf__n_estimators=1400;, score=0.400 total time=   6.3s
# [CV 5/5; 10/10] START pca__n_components=7, rf__criterion=entropy, rf__max_depth=6, rf__n_estimators=1400
# [CV 5/5; 10/10] END pca__n_components=7, rf__criterion=entropy, rf__max_depth=6, rf__n_estimators=1400;, score=0.415 total time=   7.4s
# 0.45599999999999996
# {'memory': None, 'steps': [('scaling', StandardScaler()), ('pca', PCA(n_components=9)), ('rf', RandomForestClassifier(criterion='entropy', max_depth=11, n_estimators=700,
#                        n_jobs=-1))], 'verbose': False, 'scaling': StandardScaler(), 'pca': PCA(n_components=9), 'rf': RandomForestClassifier(criterion='entropy', max_depth=11, n_estimators=700,
#                        n_jobs=-1), 'scaling__copy': True, 'scaling__with_mean': True, 'scaling__with_std': True, 'pca__copy': True, 'pca__iterated_power': 'auto', 'pca__n_components': 9, 'pca__n_oversamples': 10, 'pca__power_iteration_normalizer': 'auto', 'pca__random_state': None, 'pca__svd_solver': 'auto', 'pca__tol': 0.0, 'pca__whiten': False, 'rf__bootstrap': True, 'rf__ccp_alpha': 0.0, 'rf__class_weight': None, 'rf__criterion': 'entropy', 'rf__max_depth': 11, 'rf__max_features': 'sqrt', 'rf__max_leaf_nodes': None, 'rf__max_samples': None, 'rf__min_impurity_decrease': 0.0, 'rf__min_samples_leaf': 1, 'rf__min_samples_split': 2, 'rf__min_weight_fraction_leaf': 0.0, 'rf__n_estimators': 700, 'rf__n_jobs': -1, 'rf__oob_score': False, 'rf__random_state': None, 'rf__verbose': 0, 'rf__warm_start': False}

# %%
#Bayeian optimization with gaussian process
from functools import partial
from skopt import space
from skopt import gp_minimize

def optimize(params,param_names,x,y):
  params = dict(zip(param_names,params))
  model = ensemble.RandomForestClassifier(params)

  kf = model_selection.StratifiedKFold(n_splits=5)
  accuracies = []
  for idx in kf.split(X=x,y=y):
    train_idx,test_idx = idx[0],idx[1]
    X_train = X[train_idx]
    y_train = y[train_idx]

    X_test = X[test_idx]
    y_test = y[test_idx]

    model.fit(X_train,y_train)

    preds = model.predict(X_test)
    fold_acc = metrics.accuracy_score(y_test,preds)
    accuracies.append(fold_acc)

  return -1.0*np.mean(accuracies)

if __name__=='__main__':
  df = pd.read_csv('https://raw.githubusercontent.com/Nithya-Vasudevan/Mobile-Price-Classification/master/train.csv')
  X = df.drop('price_range', axis=1).values
  y = df.price_range.values

  param_space = [
      space.Integer(3,15,name='max_depth'),
      space.Integer(100,600,name='n_extimators'),
      space.Real(0.01,1,name='max_features',prior='uniform'),
      space.Categorical(['gini','entropy'],name='criterion')
  ]
  param_names = [
      'max_depth',
      'n_estimators',
      'criterion',
      'max_features'
  ]
  optimization_function = partial(
      optimize,
      param_names=param_names,
      x=X,
      y=y
  )
  result = gp_minimize(
      optimization_function,
      dimensions=param_space,
      n_calls=15,
      n_random_starts=10,
      verbose=10
  )
  print(
      dict(
          param_names,
          result.x
      )
  )
# Out:
# Iteration No: 1 started. Evaluating function at random point.
# ---------------------------------------------------------------------------
# InvalidParameterError                     Traceback (most recent call last)
# <ipython-input-18-ee92090cbaeb> in <cell line: 28>()
#      49       y=y
#      50   )
# ---> 51   result = gp_minimize(
#      52       optimization_function,
#      53       dimensions=param_space,
#
# /usr/local/lib/python3.10/dist-packages/skopt/optimizer/gp.py in gp_minimize(func, dimensions, base_estimator, n_calls, n_random_starts, n_initial_points, initial_point_generator, acq_func, acq_optimizer, x0, y0, random_state, verbose, callback, n_points, n_restarts_optimizer, xi, kappa, noise, n_jobs, model_queue_size, space_constraint)
#     279         )
#     280
# --> 281     return base_minimize(
#     282         func,
#     283         space,
#
# /usr/local/lib/python3.10/dist-packages/skopt/optimizer/base.py in base_minimize(func, dimensions, base_estimator, n_calls, n_random_starts, n_initial_points, initial_point_generator, acq_func, acq_optimizer, x0, y0, random_state, verbose, callback, n_points, n_restarts_optimizer, xi, kappa, n_jobs, model_queue_size, space_constraint)
#     330     for _ in range(n_calls):
#     331         next_x = optimizer.ask()
# --> 332         next_y = func(next_x)
#     333         result = optimizer.tell(next_x, next_y)
#     334         result.specs = specs
#
# <ipython-input-18-ee92090cbaeb> in optimize(params, param_names, x, y)
#      18     y_test = y[test_idx]
#      19
# ---> 20     model.fit(X_train,y_train)
#      21
#      22     preds = model.predict(X_test)
#
# /usr/local/lib/python3.10/dist-packages/sklearn/ensemble/_forest.py in fit(self, X, y, sample_weight)
#     338             Fitted estimator.
#     339         """
# --> 340         self._validate_params()
#     341
#     342         # Validate or convert input data
#
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py in _validate_params(self)
#     598         accepted constraints.
#     599         """
# --> 600         validate_parameter_constraints(
#     601             self._parameter_constraints,
#     602             self.get_params(deep=False),
#
# /usr/local/lib/python3.10/dist-packages/sklearn/utils/_param_validation.py in validate_parameter_constraints(parameter_constraints, params, caller_name)
#      95                 )
#      96
# ---> 97             raise InvalidParameterError(
#      98                 f"The {param_name!r} parameter of {caller_name} must be"
#      99                 f" {constraints_str}. Got {param_val!r} instead."
#
# InvalidParameterError: The 'n_estimators' parameter of RandomForestClassifier must be an int in the range [1, inf). Got {'max_depth': 8, 'n_estimators': 362, 'criterion': 0.5423734796105734, 'max_features': 'gini'} instead.

# %%
import torch
import torch.nn as nn
import torch.nn.functional as F
from torch.utils.data import DataLoader
from torchvision import datasets, transforms

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline

import os
from PIL import Image
from IPython.display import display

# Filter harmless warnings
import warnings
warnings.filterwarnings("ignore")

from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
with Image.open('/content/drive/MyDrive/ineuron_opencv/cat & dog/CATS_DOGS/test/CAT/10107.jpg') as im:
  display(im)
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=86x86>

# %%
# path = '/content/drive/MyDrive/ineuron_opencv/cat & dog/CATS_DOGS'
# img_names = []

# for folder,subfolders,filenames in os.walk(path):
#   for img in filenames:
#     img_names.append(folder+'/'+img)

# len(img_names)

# %%
# img_sizes = []
# rejected = []

# for item in img_names:
#   try:
#     with Image.open(item) as img:
#       img_sizes.append(img.size)

#   except:
#     rejected.append(item)

# df = pd.DataFrame(img_sizes)
# df.head()

# %%
dog = Image.open('/content/drive/MyDrive/ineuron_opencv/cat & dog/CATS_DOGS/train/DOG/14.jpg')

# %%
display(dog)
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=500x387>

# %%
dog.size
# Out:
# (500, 387)

# %%
dog.getpixel((0,0)) #--> 0 to 255
# Out:
# (90, 95, 98)

# %%
#transforing to tensor

transform = transforms.Compose([
    transforms.ToTensor()
])
im = transform(dog)
print(type(im))
print(im.shape)
# Out:
# <class 'torch.Tensor'>
# torch.Size([3, 387, 500])

# %%
#(387,500,3) -- for matplotlib
#reshape(1,2,0)
plt.imshow(np.transpose(im.numpy(),(1,2,0)))

# %%
#transforing to tensor

transform = transforms.Compose([
    transforms.Resize((224,224)),
    transforms.ToTensor()
])
im = transform(dog)
plt.imshow(np.transpose(im.numpy(),(1,2,0)))

# %%
#transforing to tensor

transform = transforms.Compose([
    transforms.Resize(250),
    transforms.CenterCrop(250),
    transforms.ToTensor()
])
im = transform(dog)
plt.imshow(np.transpose(im.numpy(),(1,2,0)))

# %%
#transforing to tensor

transform = transforms.Compose([
    transforms.Resize(250),
    transforms.CenterCrop(250),
    transforms.RandomHorizontalFlip(p=1),
    transforms.ToTensor()
])
im = transform(dog)
plt.imshow(np.transpose(im.numpy(),(1,2,0)))

# %%
#transforing to tensor

transform = transforms.Compose([
    transforms.Resize(250),
    transforms.CenterCrop(250),
    transforms.RandomHorizontalFlip(p=0.2),
    transforms.ToTensor()
])
im = transform(dog)
plt.imshow(np.transpose(im.numpy(),(1,2,0)))

# %%
#transforing to tensor

transform = transforms.Compose([
    transforms.Resize(250),
    transforms.CenterCrop(250),
    transforms.RandomHorizontalFlip(p=1),
    transforms.RandomRotation(30),
    transforms.ToTensor()
])
im = transform(dog)
plt.imshow(np.transpose(im.numpy(),(1,2,0)))

# %%
transform = transforms.Compose([
    transforms.ToTensor(),
    transforms.Normalize(mean=[0.485,0.456,0.406],std=[0.229,0.224,0.225])
])

im = transform(dog)
plt.imshow(np.transpose(im.numpy(),(1,2,0)))
# Out:
# WARNING:matplotlib.image:Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).

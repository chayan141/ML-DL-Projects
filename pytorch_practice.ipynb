# %%
#squeezing the tensor meaning removes the dimension of size 1 from the tensor shape.
##Unsqueezing meaning adds a dimension of 1 to a tensor shape

# %%
#flattening a tensor meaning, converting an multidimensional tensor to an one dimensional tensor.

# %%
#tensor_broadcasting allows operations like addition, substractions, multiplications etc to be performed
#on tensors which dont have the same shape by automatically expanding their dimensions to match each other.

# %%
#the detach function is a method used in pytorch to create new tensors that does not required gradient.

# %%
#Basic Project Structures:
#1. Prepare the Data
#2. Build the Model
#3. Train The Model
#4. Analyze the model result
